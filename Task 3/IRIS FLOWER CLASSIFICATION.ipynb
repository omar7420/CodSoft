# %% [markdown]
# # IRIS FLOWER CLASSIFICATION

# %% [markdown]
# ![Iris-setosa-2.png](attachment:Iris-setosa-2.png)

# %% [markdown]
# # Import Libraries

# %%
# For data manipulation
import pandas as pd

# For numerical operations
import numpy as np

# For data visualization
import seaborn as sns

# For plotting graphs
import matplotlib.pyplot as plt

# For splitting the dataset
from sklearn.model_selection import train_test_split as tts

# For feature scaling
from sklearn.preprocessing import StandardScaler as sc

# For Support Vector Classification
from sklearn.svm import SVC

# For model evaluation
from sklearn.metrics import classification_report as cr, accuracy_score as acc_sc

# For handling warnings
import warnings

# Ignore any warnings that may arise during execution
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load IRIS Dataset

# %%
# Load the dataset with handling the possibility of a FileNotFoundError
try:
    iris_data = pd.read_csv("IRIS.csv")
except FileNotFoundError:
    print("File not found. Please check the file path.")

# %% [markdown]
# # Information About The Dataset

# %%
# Display information about the Data, including column names, non-null counts and data types
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Display the some rows of the dataset
iris_data.head(103)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 98            5.1          2.5           3.0          1.1  Iris-versicolor
# 99            5.7          2.8           4.1          1.3  Iris-versicolor
# 100           6.3          3.3           6.0          2.5   Iris-virginica
# 101           5.8          2.7           5.1          1.9   Iris-virginica
# 102           7.1          3.0           5.9          2.1   Iris-virginica
#
# [103 rows x 5 columns]

# %%
#the shape of the data
iris_data.shape
# Out:
# (150, 5)

# %%
#the columns of the data
iris_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # Missing Values

# %%
# Check for any missing values and sum them up
iris_data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# statistics of the dataset
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Visualization

# %%
# Plotting a pairplot of the Iris dataset
sns.pairplot(iris_data, hue = 'species')

# Adding a super title to the plot
plt.suptitle('Pairplot of Iris Dataset', fontsize = 20)

# Displaying the plot
plt.show()

# %%
# Creating a KDE plot of Sepal Length
sns.kdeplot(data = iris_data, x = "sepal_length", hue = "species", fill = True, common_norm = False)

# Adding a title to the plot
plt.title('KDE Plot of Sepal Length')

# Displaying the plot
plt.show()

# %%
# Creating a KDE plot of Sepal Width
sns.kdeplot(data = iris_data, x = "sepal_width", hue = "species", fill = True, common_norm = False)

# Adding a title to the plot
plt.title('KDE Plot of Sepal Width')

# Displaying the plot
plt.show()

# %%
# Creating a KDE plot of Petal Length
sns.kdeplot(data = iris_data, x = "petal_length", hue = "species", fill = True, common_norm = False)

# Adding a title to the plot
plt.title('KDE Plot of Petal Length')

# Displaying the plot
plt.show()

# %%
# Creating a KDE plot of Petal Width
sns.kdeplot(data = iris_data, x = "petal_width", hue = "species", fill = True, common_norm = False)

# Adding a title to the plot
plt.title('KDE Plot of Petal Width')

# Displaying the plot
plt.show()

# %%
# Creating a KDE plot of all features
sns.kdeplot(data = iris_data, fill = True)

# Adding a title to the plot
plt.title('KDE Plot of All Features')

# Displaying the plot
plt.show()

# %% [markdown]
# # Training And Testing

# %%
# Separating features (X) and target labels (y)
x = iris_data.drop('species', axis=1)
y = iris_data['species']

# %%
# Splitting the dataset into training and testing sets
x_train, x_test, y_train, y_test = tts(x, y, test_size=0.4, random_state=57)

# %%
# Model training
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# # Predictions

# %%
# Predictions
y_pred = model.predict(x_test)

# %%
# Accuracy calculation
accuracy = acc_sc(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.95

# %%
# Classification report
print(cr(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.82      1.00      0.90        14
#  Iris-virginica       1.00      0.88      0.93        24
#
#        accuracy                           0.95        60
#       macro avg       0.94      0.96      0.95        60
#    weighted avg       0.96      0.95      0.95        60
